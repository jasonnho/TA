# %% [markdown]
# ### Set Up

# %% [markdown]
# ## Prediksi untuk Umbul Ponggok  ˖°𓇼🌊⋆🐚🫧

# %%
from PyABSA import pyabsa
from pyabsa import AspectSentimentTripletExtraction as ASTE
from pyabsa import ModelSaveOption, DeviceTypeOption
import warnings
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd
import torch
import os
import ast
# Out:
# /home/riset/.local/lib/python3.10/site-packages/spacy/cli/_util.py:23: DeprecationWarning: Importing 'parser.split_arg_string' is deprecated, it will only be available in 'shell_completion' in Click 9.0.
#   from click.parser import split_arg_string
# /home/riset/.local/lib/python3.10/site-packages/weasel/util/config.py:8: DeprecationWarning: Importing 'parser.split_arg_string' is deprecated, it will only be available in 'shell_completion' in Click 9.0.
#   from click.parser import split_arg_string
# [2025-06-10 13:26:57] (2.4.1.post1) PyABSA(2.4.1.post1): If your code crashes on Colab, please use the GPU runtime. Then run "pip install pyabsa[dev] -U" and restart the kernel.
# Or if it does not work, you can use v1.x versions, e.g., pip install pyabsa<2.0 -U
#
#
#
#
# WARNING: When you fails to load a checkpoint, e.g., Unexpected key(s),
# Try to downgrade transformers<=4.29.0.
# /drive0-storage/TA_Ista/Coba/PyABSA/pyabsa/framework/checkpoint_class/checkpoint_utils.py:11: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   from distutils.version import StrictVersion
# 2025-06-10 13:26:57.835485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749536817.856911    3489 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749536817.862898    3489 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749536817.878123    3489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749536817.878138    3489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749536817.878140    3489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749536817.878142    3489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-10 13:26:57.883332: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.10/multiprocessing/pool.py:268: ResourceWarning: unclosed running multiprocessing pool <multiprocessing.pool.Pool state=RUN pool_size=1>
#   _warn(f"unclosed running multiprocessing pool {self!r}",
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# [2025-06-10 13:27:09] (2.4.1.post1) PyABSA(2.4.1.post1): If your code crashes on Colab, please use the GPU runtime. Then run "pip install pyabsa[dev] -U" and restart the kernel.
# Or if it does not work, you can use v1.x versions, e.g., pip install pyabsa<2.0 -U
#
#
#
#
# WARNING: When you fails to load a checkpoint, e.g., Unexpected key(s),
# Try to downgrade transformers<=4.29.0.

# %% [markdown]
# #### Load dataset ㅤᵕ̈

# %%
FILE = 'integrated_datasets/aste_datasets/726.data_inference_desa_wisata/umbul_ponggok_reviews.txt'

# Baca ulasan dan bersihkan baris kosong
with open(FILE, 'r', encoding='utf-8') as f:
    examples = [line.strip() for line in f if line.strip() != '']

print(f"Jumlah ulasan: {len(examples)}")
# Out:
# Jumlah ulasan: 1801

# %% [markdown]
# #### Load Model જ⁀➴ ♡

# %%
triplet_extractor = ASTE.AspectSentimentTripletExtractor(
    checkpoint="AfterImprovement_f1_67.61_best",
    auto_device=DeviceTypeOption.CUDA,
)
# Out:
# [2025-06-10 13:31:51] (2.4.1.post1) ********** Available ASTE model checkpoints for Version:2.4.1.post1 (this version) **********
# [2025-06-10 13:31:51] (2.4.1.post1) ********** Available ASTE model checkpoints for Version:2.4.1.post1 (this version) **********
# [2025-06-10 13:31:51] (2.4.1.post1) Checkpoint:AfterImprovement_f1_67.61_best is not found, you can raise an issue for requesting shares of checkpoints
# [2025-06-10 13:31:51] (2.4.1.post1) No checkpoint found in Model Hub for task: AfterImprovement_f1_67.61_best
# [2025-06-10 13:31:51] (2.4.1.post1) Load sentiment classifier from checkpoints/AfterImprovement_f1_67.61_best
# [2025-06-10 13:31:51] (2.4.1.post1) config: checkpoints/AfterImprovement_f1_67.61_best/emcgcn.config
# [2025-06-10 13:31:51] (2.4.1.post1) state_dict: checkpoints/AfterImprovement_f1_67.61_best/emcgcn.state_dict
# [2025-06-10 13:31:51] (2.4.1.post1) model: None
# [2025-06-10 13:31:51] (2.4.1.post1) tokenizer: checkpoints/AfterImprovement_f1_67.61_best/emcgcn.tokenizer
# [2025-06-10 13:31:51] (2.4.1.post1) Set Model Device: cuda
# [2025-06-10 13:31:51] (2.4.1.post1) Device Name: N.A.
# /home/riset/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [2025-06-10 13:32:14] (2.4.1.post1) Can not load en_core_web_sm from spacy, try to download it in order to parse syntax tree:
# python -m spacy download en_core_web_sm
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 68.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# #### Run Predictions 🍵🍃

# %%
# run predictions & collect all result dicts
all_results = []
for ex in examples:
    res = triplet_extractor.predict(ex)
    # ensure we always have a list of dicts
    batch = [res] if isinstance(res, dict) else res
    all_results.extend(batch)
# Out:
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata lokal yang cukup bisa melampiaskan hasrat foto - foto dalam air bersama ikan', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata lokal yang cukup bisa melampiaskan hasrat foto - foto dalam air bersama ikan', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'enak tidak terlalu ramai pas hari kerja', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'enak tidak terlalu ramai pas hari kerja', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tiap ke jogja wajib banget sih kesini . air bawahnya biru banget', 'Triplets': [{'Aspect': 'air bawahnya', 'Opinion': 'biru banget', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tiap ke jogja wajib banget sih kesini . air bawahnya biru banget', 'Triplets': [{'Aspect': 'air bawahnya', 'Opinion': 'biru banget', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'luar biasa', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'luar biasa', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'umbul ponggok sangat keren karena merupakan desa wisata yang dikelola masyarakat', 'Triplets': [{'Aspect': 'umbul ponggok', 'Opinion': 'sangat keren', 'Polarity': 'Positive'}, {'Aspect': 'umbul ponggok', 'Opinion': 'dikelola masyarakat', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'umbul ponggok sangat keren karena merupakan desa wisata yang dikelola masyarakat', 'Triplets': [{'Aspect': 'umbul ponggok', 'Opinion': 'sangat keren', 'Polarity': 'Positive'}, {'Aspect': 'umbul ponggok', 'Opinion': 'dikelola masyarakat', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat sangat bagus , kolam bersih dan tidak ada bau amis , saya rekam menggunakan kamera android biasa dan memang di dalam air tidak perlu di edit atau bagaimana . aslinya sama keren nya dengan foto - foto yang ada di ig maupun google . tapi untuk maksimal nya baiknya menggunakan gopro , dan ada juga penyewaan nya di tempat .', 'Triplets': [{'Aspect': 'tempat', 'Opinion': 'sangat bagus', 'Polarity': 'Positive'}, {'Aspect': 'kolam', 'Opinion': 'bersih', 'Polarity': 'Positive'}, {'Aspect': 'kolam', 'Opinion': 'tidak ada bau amis', 'Polarity': 'Positive'}, {'Aspect': 'penyewaan', 'Opinion': 'ada', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat sangat bagus , kolam bersih dan tidak ada bau amis , saya rekam menggunakan kamera android biasa dan memang di dalam air tidak perlu di edit atau bagaimana . aslinya sama keren nya dengan foto - foto yang ada di ig maupun google . tapi untuk maksimal nya baiknya menggunakan gopro , dan ada juga penyewaan nya di tempat .', 'Triplets': [{'Aspect': 'tempat', 'Opinion': 'sangat bagus', 'Polarity': 'Positive'}, {'Aspect': 'kolam', 'Opinion': 'bersih', 'Polarity': 'Positive'}, {'Aspect': 'kolam', 'Opinion': 'tidak ada bau amis', 'Polarity': 'Positive'}, {'Aspect': 'penyewaan', 'Opinion': 'ada', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:29] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 
 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolam alami yang di kelola secara profesional , keren konsep nya , wahana di poto di dalam air , semoga bisa di tiru oleh daerah sumbar yang juga punya banyak potensi seperti ini', 'Triplets': [{'Aspect': 'konsep', 'Opinion': 'keren', 'Polarity': 'Positive'}, {'Aspect': 'konsep', 'Opinion': 'di dalam air', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolam alami yang di kelola secara profesional , keren konsep nya , wahana di poto di dalam air , semoga bisa di tiru oleh daerah sumbar yang juga punya banyak potensi seperti ini', 'Triplets': [{'Aspect': 'konsep', 'Opinion': 'keren', 'Polarity': 'Positive'}, {'Aspect': 'konsep', 'Opinion': 'di dalam air', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'liburan keluarga asik . ada tempat sewa alat renang lengkap , foto underwater , guide renangnya juga ada . air murni ya , tidak ditambah kimia , jadi betah lama2 renang sama ikan', 'Triplets': [{'Aspect': 'liburan keluarga', 'Opinion': 'asik', 'Polarity': 'Positive'}, {'Aspect': 'tempat sewa alat renang', 'Opinion': 'lengkap', 'Polarity': 'Positive'}, {'Aspect': 'guide renangnya', 'Opinion': 'ada', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'liburan keluarga asik . ada tempat sewa alat renang lengkap , foto underwater , guide renangnya juga ada . air murni ya , tidak ditambah kimia , jadi betah lama2 renang sama ikan', 'Triplets': [{'Aspect': 'liburan keluarga', 'Opinion': 'asik', 'Polarity': 'Positive'}, {'Aspect': 'tempat sewa alat renang', 'Opinion': 'lengkap', 'Polarity': 'Positive'}, {'Aspect': 'guide renangnya', 'Opinion': 'ada', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mata air dan tempat wisata yang selalu di kunjungin kalo pas mudik ! paling enak si berenang di sini , soalnya air nya ngalir karena langsung dari mata air nya , sekarang tempatnya udah bagus banget bisa foto langsung di dalem bareng ikan ikan', 'Triplets': [{'Aspect': 'tempat wisata', 'Opinion': 'selalu di kunjungin', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'ngalir', 'Polarity': 'Positive'}, {'Aspect': 'tempatnya', 'Opinion': 'bagus banget', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mata air dan tempat wisata yang selalu di kunjungin kalo pas mudik ! paling enak si berenang di sini , soalnya air nya ngalir karena langsung dari mata air nya , sekarang tempatnya udah bagus banget bisa foto langsung di dalem bareng ikan ikan', 'Triplets': [{'Aspect': 'tempat wisata', 'Opinion': 'selalu di kunjungin', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'ngalir', 'Polarity': 'Positive'}, {'Aspect': 'tempatnya', 'Opinion': 'bagus banget', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mungkin sudah 8 tahun yl ke umbul ponggok . masih sederhana tapi sudah sangat amazing . ikan buanyak sekali dan aneka spot foto dalam air juga sudah tersedia . makanan dan minuman dijajakan di sekitar kolam dengan harga terjangkau . airnya sangat jernih dan segar karena langsung dari sumber air . lokasi gampang ditemukan . area parkir sudah lumayan luas tetapi karena pengunjung banyak jadi terlihat penuh .', 'Triplets': [{'Aspect': 'ikan', 'Opinion': 'buanyak sekali', 'Polarity': 'Positive'}, {'Aspect': 'makanan', 'Opinion': 'tersedia', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'terjangkau', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'sangat jernih', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'segar', 'Polarity': 'Positive'}, {'Aspect': 'lokasi', 'Opinion': 'gampang ditemukan', 'Polarity': 'Positive'}, {'Aspect': 'area parkir', 'Opinion': 'lumayan luas', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:30] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 
 'Triplets': [{'Aspect': 'tempatnya', 'Opinion': 'bagus', 'Polarity': 'Positive'}, {'Aspect': 'tempatnya', 'Opinion': 'nyaman', 'Polarity': 'Positive'}, {'Aspect': 'tempatnya', 'Opinion': 'cukup bersih', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'jernih', 'Polarity': 'Positive'}, {'Aspect': 'refreshing keluarga', 'Opinion': 'sejuk', 'Polarity': 'Positive'}, {'Aspect': 'refreshing keluarga', 'Opinion': 'cocok', 'Polarity': 'Positive'}, {'Aspect': 'harga tiket', 'Opinion': '15ribu', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mendapatkan pengalaman yang unik , berenang bersama ikan ikan', 'Triplets': [{'Aspect': 'pengalaman', 'Opinion': 'unik', 'Polarity': 'Positive'}, {'Aspect': 'berenang', 'Opinion': 'bersama ikan ikan', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mendapatkan pengalaman yang unik , berenang bersama ikan ikan', 'Triplets': [{'Aspect': 'pengalaman', 'Opinion': 'unik', 'Polarity': 'Positive'}, {'Aspect': 'berenang', 'Opinion': 'bersama ikan ikan', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata air tawar yang keren , alami , seger , murah meriah .', 'Triplets': [{'Aspect': 'wisata air tawar', 'Opinion': 'keren', 'Polarity': 'Positive'}, {'Aspect': 'wisata air tawar', 'Opinion': 'alami', 'Polarity': 'Positive'}, {'Aspect': 'wisata air tawar', 'Opinion': 'seger', 'Polarity': 'Positive'}, {'Aspect': 'wisata air tawar', 'Opinion': 'murah meriah', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata air tawar yang keren , alami , seger , murah meriah .', 'Triplets': [{'Aspect': 'wisata air tawar', 'Opinion': 'keren', 'Polarity': 'Positive'}, {'Aspect': 'wisata air tawar', 'Opinion': 'alami', 'Polarity': 'Positive'}, {'Aspect': 'wisata air tawar', 'Opinion': 'seger', 'Polarity': 'Positive'}, {'Aspect': 'wisata air tawar', 'Opinion': 'murah meriah', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'buat renang / terapi bagus banget karena itu umbul asli , tempat nyaman , nyantai juga bisa banget ada kafenya juga', 'Triplets': [{'Aspect': 'renang / terapi', 'Opinion': 'bagus banget', 'Polarity': 'Positive'}, {'Aspect': 'tempat', 'Opinion': 'nyaman', 'Polarity': 'Positive'}, {'Aspect': 'kafenya', 'Opinion': 'ada', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'buat renang / terapi bagus banget karena itu umbul asli , tempat nyaman , nyantai juga bisa banget ada kafenya juga', 'Triplets': [{'Aspect': 'renang / terapi', 'Opinion': 'bagus banget', 'Polarity': 'Positive'}, {'Aspect': 'tempat', 'Opinion': 'nyaman', 'Polarity': 'Positive'}, {'Aspect': 'kafenya', 'Opinion': 'ada', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'airnya dingin pemandangannya dlm air bagus', 'Triplets': [{'Aspect': 'airnya', 'Opinion': 'dingin', 'Polarity': 'Positive'}, {'Aspect': 'pemandangannya', 'Opinion': 'air', 'Polarity': 'Positive'}, {'Aspect': 'pemandangannya', 'Opinion': 'bagus', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'airnya dingin pemandangannya dlm air bagus', 'Triplets': [{'Aspect': 'airnya', 'Opinion': 'dingin', 'Polarity': 'Positive'}, {'Aspect': 'pemandangannya', 'Opinion': 'air', 'Polarity': 'Positive'}, {'Aspect': 'pemandangannya', 'Opinion': 'bagus', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 
 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'air bersih lingkungan bersih , cuma lantainya lumayan licin harus sering - sering dibersihkan : )', 'Triplets': [{'Aspect': 'lingkungan', 'Opinion': 'bersih', 'Polarity': 'Positive'}, {'Aspect': 'lantainya', 'Opinion': 'lumayan licin', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat yang bagus untuk refreshing . bisa berenang sekaligus foto dan membuat video .', 'Triplets': [{'Aspect': 'tempat', 'Opinion': 'bagus untuk refreshing', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat yang bagus untuk refreshing . bisa berenang sekaligus foto dan membuat video .', 'Triplets': [{'Aspect': 'tempat', 'Opinion': 'bagus untuk refreshing', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempatnya bagus , perlu pembenahan sedikit sedikit .', 'Triplets': [{'Aspect': 'tempatnya', 'Opinion': 'bagus', 'Polarity': 'Positive'}, {'Aspect': 'tempatnya', 'Opinion': 'perlu', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempatnya bagus , perlu pembenahan sedikit sedikit .', 'Triplets': [{'Aspect': 'tempatnya', 'Opinion': 'bagus', 'Polarity': 'Positive'}, {'Aspect': 'tempatnya', 'Opinion': 'perlu', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolam renang mata air untuk snorkeling dan diving yang nyaman dan segaar', 'Triplets': [{'Aspect': 'kolam renang mata air', 'Opinion': 'nyaman', 'Polarity': 'Positive'}, {'Aspect': 'kolam renang mata air', 'Opinion': 'segaar', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolam renang mata air untuk snorkeling dan diving yang nyaman dan segaar', 'Triplets': [{'Aspect': 'kolam renang mata air', 'Opinion': 'nyaman', 'Polarity': 'Positive'}, {'Aspect': 'kolam renang mata air', 'Opinion': 'segaar', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'sensasi berenang dengan ikan koi', 'Triplets': [{'Aspect': 'berenang', 'Opinion': 'dengan ikan koi', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:32] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'sensasi berenang dengan ikan koi', 'Triplets': [{'Aspect': 'berenang', 'Opinion': 'dengan ikan koi', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat yang bagus untuk liburan bersama keluarga', 'Triplets': [{'Aspect': 'tempat', 'Opinion': 'bagus untuk liburan bersama keluarga', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat yang bagus untuk liburan bersama keluarga', 'Triplets': [{'Aspect': 'tempat', 'Opinion': 'bagus untuk liburan bersama keluarga', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolam jernih dan dingin dengan ikan jinak .', 'Triplets': [{'Aspect': 'kolam', 'Opinion': 'jernih', 'Polarity': 'Positive'}, {'Aspect': 'ikan', 'Opinion': 'dingin', 'Polarity': 'Positive'}, {'Aspect': 'ikan', 'Opinion': 'jinak', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolam jernih dan dingin dengan ikan jinak .', 'Triplets': [{'Aspect': 'kolam', 'Opinion': 'jernih', 'Polarity': 'Positive'}, {'Aspect': 'ikan', 'Opinion': 'dingin', 'Polarity': 'Positive'}, {'Aspect': 'ikan', 'Opinion': 'jinak', 'Polarity': 'Neutral'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempatnya lumayan bersih , tempat bilas nya oke tidak ada sampah berserakan . untuk kolam , airnya sangat jernih dan dingin , ikan ikan yang di dalam kolam tidak agresif . namun harap berhati - hati karena dasar kolam adalah batu batu jadi sangat licin dan tidak rata . disediakan juga penyewaan alat alat renang seperti pelampung .', 'Triplets': [{'Aspect': 'tempatnya', 'Opinion': 'lumayan bersih', 'Polarity': 'Positive'}, {'Aspect': 'tempat bilas', 'Opinion': 'oke', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'sangat jernih', 'Polarity': 'Positive'}, {'Aspect': 'ikan ikan', 'Opinion': 'dingin', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempatnya lumayan bersih , tempat bilas nya oke tidak ada sampah berserakan . untuk kolam , airnya sangat jernih dan dingin , ikan ikan yang di dalam kolam tidak agresif . namun harap berhati - hati karena dasar kolam adalah batu batu jadi sangat licin dan tidak rata . disediakan juga penyewaan alat alat renang seperti pelampung .', 'Triplets': [{'Aspect': 'tempatnya', 'Opinion': 'lumayan bersih', 'Polarity': 'Positive'}, {'Aspect': 'tempat bilas', 'Opinion': 'oke', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'sangat jernih', 'Polarity': 'Positive'}, {'Aspect': 'ikan ikan', 'Opinion': 'dingin', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'dan nilai jual yang ada di sini adalah kita bisa berfoto di dasar air dengan ikan ikan yang berkumpul di sekitar kita .', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'dan nilai jual yang ada di sini adalah kita bisa berfoto di dasar air dengan ikan ikan yang berkumpul di sekitar kita .', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'asik seru aman soalnya pake pelampung . tiket cuma 15ribu', 'Triplets': [{'Aspect': 'tiket', 'Opinion': 'cuma 15ribu', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'asik seru aman soalnya pake pelampung . tiket cuma 15ribu', 'Triplets': [{'Aspect': 'tiket', 'Opinion': 'cuma 15ribu', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tiket masuk dan harga makanannya sangat bersahabat dengan pengunjung parkirpun tidak ajimumpung', 'Triplets': [{'Aspect': 'harga makanannya', 'Opinion': 'sangat bersahabat dengan', 'Polarity': 'Positive'}, {'Aspect': 'parkirpun', 'Opinion': 'tidak', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tiket masuk dan harga makanannya sangat bersahabat dengan pengunjung parkirpun tidak ajimumpung', 'Triplets': [{'Aspect': 'harga makanannya', 'Opinion': 'sangat bersahabat dengan', 'Polarity': 'Positive'}, {'Aspect': 'parkirpun', 'Opinion': 'tidak', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata airnya alami , ikannya menarik , peralatan renang cukup banyak , sewanya murah , perlu diperbaiki dalam hal kebersihannya .', 'Triplets': [{'Aspect': 'wisata airnya', 'Opinion': 'alami', 'Polarity': 'Positive'}, {'Aspect': 'ikannya', 'Opinion': 'menarik', 'Polarity': 'Positive'}, {'Aspect': 'peralatan renang', 'Opinion': 'cukup banyak', 'Polarity': 'Positive'}, {'Aspect': 'sewanya', 'Opinion': 'murah', 'Polarity': 'Positive'}, {'Aspect': 'sewanya', 'Opinion': 'perlu', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata airnya alami , ikannya menarik , peralatan renang cukup banyak , sewanya murah , perlu diperbaiki dalam hal kebersihannya .', 'Triplets': [{'Aspect': 'wisata airnya', 'Opinion': 'alami', 'Polarity': 'Positive'}, {'Aspect': 'ikannya', 'Opinion': 'menarik', 'Polarity': 'Positive'}, {'Aspect': 'peralatan renang', 'Opinion': 'cukup banyak', 'Polarity': 'Positive'}, {'Aspect': 'sewanya', 'Opinion': 'murah', 'Polarity': 'Positive'}, {'Aspect': 'sewanya', 'Opinion': 'perlu', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'murah meriah menyenangkan', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'murah meriah menyenangkan', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'enak buat refres pikiran', 'Triplets': [{'Aspect': 'refres', 'Opinion': 'enak', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'enak buat refres pikiran', 'Triplets': [{'Aspect': 'refres', 'Opinion': 'enak', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:33] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'kolamnya luas , dspat gratis pelampung , balita saya dan suami sangat senang ke sini .', 'Triplets': [{'Aspect': 'kolamnya', 'Opinion': 'luas', 'Polarity': 'Positive'}], 'True Triplets': []}
# ...
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata desa yang dimanage sangat apik . saya bawa teman saya yang orang asing dan tetap reviewnya sangat baik biarpun tidak ada layanan yang berbahasa inggris . airnya jernih , koi2nya menambah indah kolamnya . jangan lupa sesi foto underwater juga kalau ke sini . bakal ke sini lagi untuk renang .', 'Triplets': [{'Aspect': 'wisata desa', 'Opinion': 'sangat apik', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'sangat baik', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'tidak', 'Polarity': 'Negative'}, {'Aspect': 'airnya', 'Opinion': 'jernih', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'cukuplah menambah referensi tempat renang', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'cukuplah menambah referensi tempat renang', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'bagus', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'bagus', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'airnya dingin , bersih , segar', 'Triplets': [{'Aspect': 'airnya', 'Opinion': 'dingin', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'bersih', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'segar', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'airnya dingin , bersih , segar', 'Triplets': [{'Aspect': 'airnya', 'Opinion': 'dingin', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'bersih', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'segar', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata bagus', 'Triplets': [{'Aspect': 'wisata', 'Opinion': 'bagus', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wisata bagus', 'Triplets': [{'Aspect': 'wisata', 'Opinion': 'bagus', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'airnya segar , jernih , dan pemandangan ikan yang eksotis', 'Triplets': [{'Aspect': 'airnya', 'Opinion': 'segar', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'jernih', 'Polarity': 'Positive'}, {'Aspect': 'pemandangan ikan', 'Opinion': 'eksotis', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'airnya segar , jernih , dan pemandangan ikan yang eksotis', 'Triplets': [{'Aspect': 'airnya', 'Opinion': 'segar', 'Polarity': 'Positive'}, {'Aspect': 'airnya', 'Opinion': 'jernih', 'Polarity': 'Positive'}, {'Aspect': 'pemandangan ikan', 'Opinion': 'eksotis', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mata ari yang mnyegarkan .', 'Triplets': [{'Aspect': 'mata', 'Opinion': 'ari', 'Polarity': 'Neutral'}, {'Aspect': 'mata', 'Opinion': 'mnyegarkan', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'mata ari yang mnyegarkan .', 'Triplets': [{'Aspect': 'mata', 'Opinion': 'ari', 'Polarity': 'Neutral'}, {'Aspect': 'mata', 'Opinion': 'mnyegarkan', 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wow . salah satu umbul terbaik di klaten . air alami yang tentunya sejuk dan segar . fasilitas pendukung lengkap , ada loker juga , toilet berbayar ya . makan minum juga tersedia bisa foto di bawah air juga di sini harga tiket masuk : 15k toilet : 2k foto underwater : start mulai 60k nice lah', 'Triplets': [{'Aspect': 'umbul', 'Opinion': 'terbaik di klaten', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'alami', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'sejuk', 'Polarity': 'Positive'}, {'Aspect': 'fasilitas pendukung', 'Opinion': 'segar', 'Polarity': 'Positive'}, {'Aspect': 'fasilitas pendukung', 'Opinion': 'lengkap', 'Polarity': 'Positive'}, {'Aspect': 'loker', 'Opinion': 'ada', 'Polarity': 'Neutral'}, {'Aspect': 'toilet', 'Opinion': 'berbayar', 'Polarity': 'Neutral'}, {'Aspect': 'makan minum', 'Opinion': 'tersedia', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'wow . salah satu umbul terbaik di klaten . air alami yang tentunya sejuk dan segar . fasilitas pendukung lengkap , ada loker juga , toilet berbayar ya . makan minum juga tersedia bisa foto di bawah air juga di sini harga tiket masuk : 15k toilet : 2k foto underwater : start mulai 60k nice lah', 'Triplets': [{'Aspect': 'umbul', 'Opinion': 'terbaik di klaten', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'alami', 'Polarity': 'Positive'}, {'Aspect': 'air', 'Opinion': 'sejuk', 'Polarity': 'Positive'}, {'Aspect': 'fasilitas pendukung', 'Opinion': 'segar', 'Polarity': 'Positive'}, {'Aspect': 'fasilitas pendukung', 'Opinion': 'lengkap', 'Polarity': 'Positive'}, {'Aspect': 'loker', 'Opinion': 'ada', 'Polarity': 'Neutral'}, {'Aspect': 'toilet', 'Opinion': 'berbayar', 'Polarity': 'Neutral'}, {'Aspect': 'makan minum', 'Opinion': 'tersedia', 'Polarity': 'Positive'}], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'baguuus banget untuk yang hobi fotografi di bawah air , kereeeeen broo', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:57] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'baguuus banget untuk yang hobi fotografi di bawah air , kereeeeen broo', 'Triplets': [], 'True Triplets': []}
# [2025-06-10 13:32:58] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence
 'Polarity': 'Negative'}], 'True Triplets': []}
# [2025-06-10 13:32:58] (2.4.1.post1) Batch: 0 {'sentence_id': 0, 'sentence': 'tempat untuk cuci tangan tidak tersedia , mau pipis dan mandi berbayar', 'Triplets': [{'Aspect': 'tempat untuk cuci tangan', 'Opinion': 'tidak tersedia', 'Polarity': 'Negative'}, {'Aspect': 'mandi', 'Opinion': 'berbayar', 'Polarity': 'Negative'}], 'True Triplets': []}

# %%
# Buat list of records untuk DataFrame
records = []
for entry in all_results:
    records.append({
        "Sentence": entry.get("sentence", ""),
        "Predicted Triplets": str(entry.get("Triplets", [])),
    })

# Konversi ke DataFrame
df = pd.DataFrame(records)

# Tampilkan beberapa baris pertama
print(df.head())
# Out:
#                                             Sentence  \
# 0  wisata lokal yang cukup bisa melampiaskan hasr...
# 1            enak tidak terlalu ramai pas hari kerja
# 2  tiap ke jogja wajib banget sih kesini . air ba...
# 3                                         luar biasa
# 4  umbul ponggok sangat keren karena merupakan de...
#
#                                   Predicted Triplets
# 0                                                 []
# 1                                                 []
# 2  [{'Aspect': 'air bawahnya', 'Opinion': 'biru b...
# 3                                                 []
# 4  [{'Aspect': 'umbul ponggok', 'Opinion': 'sanga...

# %% [markdown]
# #### Analisis Jumlah Triplet

# %%
# Buat kolom yang menghitung jumlah Predicted Triplets per baris
def count_predicted(x):
    # Jika berbentuk string (misal "[{'Aspect':...}...]"), parse dulu
    if isinstance(x, str):
        try:
            lst = ast.literal_eval(x)
            return len(lst)
        except (ValueError, SyntaxError):
            return 0
    # Jika sudah berbentuk list, cukup pakai len(x)
    if isinstance(x, list):
        return len(x)
    return 0

df['Count Predicted Triplets'] = df['Predicted Triplets'].apply(count_predicted)

print(f"Total triplet: {df['Count Predicted Triplets'].sum()}")
# Out:
# Total triplet: 3210

# %%
df
# Out:
#                                                Sentence  \
# 0     wisata lokal yang cukup bisa melampiaskan hasr...
# 1               enak tidak terlalu ramai pas hari kerja
# 2     tiap ke jogja wajib banget sih kesini . air ba...
# 3                                            luar biasa
# 4     umbul ponggok sangat keren karena merupakan de...
# ...                                                 ...
# 1796                    tempatnya mantap untuk rfresing
# 1797                                  alami tempatnya ,
# 1798                                       tempat bagus
# 1799  seharusnya dibuat larangan merokok . di sini k...
# 1800  tempat pemandian mata air yang paling mantap ,...
#
#                                      Predicted Triplets  \
# 0                                                    []
# 1                                                    []
# 2     [{'Aspect': 'air bawahnya', 'Opinion': 'biru b...
# 3                                                    []
# 4     [{'Aspect': 'umbul ponggok', 'Opinion': 'sanga...
# ...                                                 ...
# 1796  [{'Aspect': 'tempatnya', 'Opinion': 'mantap', ...
# 1797  [{'Aspect': 'tempatnya', 'Opinion': 'alami', '...
# 1798  [{'Aspect': 'tempat', 'Opinion': 'bagus', 'Pol...
# 1799                                                 []
# 1800  [{'Aspect': 'harga', 'Opinion': 'paling mantap...
#
#       Count Predicted Triplets
# 0                            0
# 1                            0
# 2                            1
# 3                            0
# 4                            2
# ...                        ...
# 1796                         1
# 1797                         1
# 1798                         1
# 1799                         0
# 1800                         5
#
# [1801 rows x 3 columns]

# %%
# Filter review dengan count = 0
df_zero = df[df['Count Predicted Triplets'] == 0]

# Tampilkan hanya kolom Sentence & Predicted Triplets
print(f"Jumlah ulasan tanpa triplet: {len(df_zero)}\n")
print(df_zero[['Sentence', 'Predicted Triplets']])
# Out:
# Jumlah ulasan tanpa triplet: 406
#
#                                                Sentence Predicted Triplets
# 0     wisata lokal yang cukup bisa melampiaskan hasr...                 []
# 1               enak tidak terlalu ramai pas hari kerja                 []
# 3                                            luar biasa                 []
# 9                      keep it up , overall bintang 5++                 []
# 17                           adem dan enak buat nyantai                 []
# ...                                                 ...                ...
# 1784  lebaran kemaren kesini sama mama papa kakak om...                 []
# 1787                                                                    []
# 1789                                             mantap                 []
# 1792                         cukup satu kata . sempurna                 []
# 1799  seharusnya dibuat larangan merokok . di sini k...                 []
#
# [406 rows x 2 columns]

# %%
# Simpan ke file Excel
output_path = 'hasil_prediksi_umbul_ponggok_absa.xlsx'
df.to_excel(output_path, index=False)

print(f"Hasil prediksi berhasil disimpan ke: {output_path}")
# Out:
# Hasil prediksi berhasil disimpan ke: hasil_prediksi_umbul_ponggok_absa.xlsx

# %% [markdown]
# ### Pemecahan Hasil Prediksi

# %%
import ast
import pandas as pd

# Fungsi untuk parse Predicted Triplets (string → list)
def parse_triplets(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except Exception:
            return []
    elif isinstance(x, list):
        return x
    else:
        return []

# Bangun list of rows untuk df_flat
rows = []
for _, row in df.iterrows():
    sentence = row['Sentence']
    triplet_list = parse_triplets(row['Predicted Triplets'])
    
    if triplet_list:
        for t in triplet_list:
            rows.append({
                'Sentence': sentence,
                'Aspect': t.get('Aspect'),
                'Opinion': t.get('Opinion'),
                'Sentiment': t.get('Polarity')  # pola key sesuai dict prediksi
            })
    else:
        # Jika tidak ada triplet, tetap masukkan sekali dengan None
        rows.append({
            'Sentence': sentence,
            'Aspect': None,
            'Opinion': None,
            'Sentiment': None
        })

# Buat DataFrame
df_flat = pd.DataFrame(rows)

# Cek hasil
print(df_flat.head())
print(f"Total baris di df_flat: {len(df_flat)}")
# Out:
#                                             Sentence         Aspect  \
# 0  wisata lokal yang cukup bisa melampiaskan hasr...           None
# 1            enak tidak terlalu ramai pas hari kerja           None
# 2  tiap ke jogja wajib banget sih kesini . air ba...   air bawahnya
# 3                                         luar biasa           None
# 4  umbul ponggok sangat keren karena merupakan de...  umbul ponggok
#
#         Opinion Sentiment
# 0          None      None
# 1          None      None
# 2   biru banget  Positive
# 3          None      None
# 4  sangat keren  Positive
# Total baris di df_flat: 3616

# %% [markdown]
# #### Persebaran Sentimen

# %%
# skip klo masih fresh habis nge-predict
excel_path = "hasil_prediksi_umbul_ponggok_absa.xlsx"
df_flat = pd.read_excel(excel_path)

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt

# df = pd.read_excel('hasil_prediksi_kampung_blekok.xlsx')

# Fungsi parsing kolom Predicted Triplets
def parse_triplets(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except:
            return []
    elif isinstance(x, list):
        return x
    else:
        return []

# Flatten list triplets ke DataFrame df_flat
rows = []
for _, row in df.iterrows():
    triplets = parse_triplets(row['Predicted Triplets'])
    if triplets:
        for t in triplets:
            rows.append(t)  # t = {'Aspect','Opinion','Polarity'}
    else:
        rows.append({'Aspect': None, 'Opinion': None, 'Polarity': None})
df_flat = pd.DataFrame(rows)

# Ubah ke label Bahasa Indonesia
mapping = {'Positive': 'Positif', 'Negative': 'Negatif', 'Neutral': 'Netral'}
df_flat['Sentiment_ID'] = df_flat['Polarity'].map(mapping).fillna(df_flat['Polarity'])

# Hitung distribusi dan persentase
counts = df_flat['Sentiment_ID'].value_counts()
labels = counts.index.tolist() 
sizes  = counts.values
total  = sizes.sum()
percentages = [s/total*100 for s in sizes]

# Buat label 2-baris: sentimen di atas, persen di bawah
label_strs = [
    f"{lbl}\n{pct:.2f}%"
    for lbl, pct in zip(labels, percentages)
]

color_map = {'Positif':'#58A34E','Negatif':'#DF362D','Netral':'#CDCDCD'}
colors = [color_map[lbl] for lbl in labels]

# Plot
plt.figure(figsize=(6,6))
plt.pie(
    sizes,
    labels=label_strs,
    colors=colors,
    startangle=90,
    wedgeprops={'edgecolor':'white','linewidth':1},
    textprops={'fontsize':12}
)
plt.axis('equal')
plt.title("Distribusi Sentimen Triplet", pad=20)
plt.tight_layout()
plt.savefig('persebaran_sentimen_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Hitung distribusi
counts = df_flat['Sentiment_ID'].value_counts()

# Cetak jumlah untuk masing-masing sentimen
print("Positif :", counts.get('Positif', 0))
print("Negatif :", counts.get('Negatif', 0))
print("Netral :", counts.get('Netral', 0))
# Out:
# Positif : 2393
# Negatif : 347
# Netral : 470

# %% [markdown]
# #### Hapus Nilai NaN

# %%
df_flat
# Out:
#              Aspect                Opinion  Polarity Sentiment_ID
# 0              None                   None      None         None
# 1              None                   None      None         None
# 2      air bawahnya            biru banget  Positive      Positif
# 3              None                   None      None         None
# 4     umbul ponggok           sangat keren  Positive      Positif
# ...             ...                    ...       ...          ...
# 3611          harga          paling mantap  Positive      Positif
# 3612          harga  tidak ada yang nembak  Negative      Negatif
# 3613          mandi           sangat segar  Positive      Positif
# 3614      ikan ikan                 banyak  Positive      Positif
# 3615      ikan ikan          sangat cantik  Positive      Positif
#
# [3616 rows x 4 columns]

# %%
# Drop semua baris yang punya NaN di _semua_ kolom
df_flat = df_flat.dropna()

# %%
df_flat
# Out:
#              Aspect                Opinion  Polarity Sentiment_ID
# 2      air bawahnya            biru banget  Positive      Positif
# 4     umbul ponggok           sangat keren  Positive      Positif
# 5     umbul ponggok    dikelola masyarakat   Neutral       Netral
# 6            tempat           sangat bagus  Positive      Positif
# 7             kolam                 bersih  Positive      Positif
# ...             ...                    ...       ...          ...
# 3611          harga          paling mantap  Positive      Positif
# 3612          harga  tidak ada yang nembak  Negative      Negatif
# 3613          mandi           sangat segar  Positive      Positif
# 3614      ikan ikan                 banyak  Positive      Positif
# 3615      ikan ikan          sangat cantik  Positive      Positif
#
# [3210 rows x 4 columns]

# %% [markdown]
# ## Analisis Positif ⋆｡‧˚ʚ🍓ɞ˚‧｡⋆

# %%
# skip kalo masih fresshhhhhhhhhh
excel_path = "hasil_separate_prediction_kampung_blekok.xlsx"
df_flat_bfr = pd.read_excel(excel_path)

# %% [markdown]
# #### Persebaran Aspek Positif (Before)

# %%
import matplotlib.pyplot as plt

# 1. Filter hanya untuk polarity “Positive”
df_pos_bfr = df_flat[df_flat['Polarity'] == 'Positive']

# 2. Hitung frekuensi aspek dan ambil top 25
aspect_counts = df_pos_bfr['Aspect'].value_counts().head(25)

# 3. Urutkan ascending supaya bar terbesar di atas
aspect_counts = aspect_counts.sort_values()

# 4. Plot
plt.figure(figsize=(8, 10))
bars = plt.barh(
    aspect_counts.index,
    aspect_counts.values,
    color='#58A34E',
    edgecolor='white',
    height=0.8
)

# 5. Annotasi angka di ujung batang
for bar in bars:
    w = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        w + max(aspect_counts.values) * 0.01,  # sedikit ke kanan
        y,
        str(int(w)),
        va='center',
        fontsize=10
    )

plt.xlabel('Frekuensi')
plt.xlim(0, aspect_counts.values.max() * 1.15)
plt.ylabel('Aspek')
# plt.title('Top 25 Aspek Terpopuler (Only Positive) di Kampung Blekok')
plt.tight_layout()
plt.savefig('top25_aspek_positive_umbul_ponggok-before.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Hapus Akhiran "-nya" yang terdapat pada Aspek

# %%
def strip_nya(aspect: str) -> str:
    # pastikan tipe string
    if not isinstance(aspect, str):
        return aspect
    # hapus “-nya” dulu, baru “nya”
    if aspect.endswith('-nya'):
        return aspect[:-4]       # buang 4 karakter (“-nya”)
    if aspect.endswith('nya'):
        return aspect[:-3]       # buang 3 karakter (“nya”)
    return aspect

# Terapkan ke kolom Aspect
df_flat['Aspect'] = df_flat['Aspect'].apply(strip_nya)
# Out:
# /tmp/ipykernel_3489/3773486667.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat['Aspect'] = df_flat['Aspect'].apply(strip_nya)

# %% [markdown]
# ### Pemberhentian Sementara Untuk Normalisasi Aspek 𓆉 ⋆.˚ 𓆝⋆.˚

# %%
df_flat.to_excel('hasil_separate_prediction_kampung_blekok.xlsx', index=False)

# %% [markdown]
# #### Persebaran Aspek Positif (After)

# %%
# Load file yang aspek udah diedit
excel_path = "edited_hasil_separate_prediction_kampung_blekok.xlsx"
df_flat = pd.read_excel(excel_path)

# %%
import matplotlib.pyplot as pl

# Filter hanya untuk polarity “Positive”
df_pos = df_flat[df_flat['Polarity'] == 'Positive']

# Hitung frekuensi aspek dan ambil top 25
aspect_counts = df_pos['Aspect'].value_counts().head(25)

# Urutkan ascending supaya bar terbesar di atas
aspect_counts = aspect_counts.sort_values()

# Plot
plt.figure(figsize=(8, 10))
bars = plt.barh(
    aspect_counts.index,
    aspect_counts.values,
    color='#58A34E',
    edgecolor='white',
    height=0.8
)

# Annotasi angka di ujung batang
for bar in bars:
    w = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        w + max(aspect_counts.values) * 0.01,  # sedikit ke kanan
        y,
        str(int(w)),
        va='center',
        fontsize=10
    )

plt.xlabel('Frekuensi')
plt.xlim(0, aspect_counts.values.max() * 1.15)
plt.ylabel('Aspek')
# plt.title('Top 25 Aspek Terpopuler (Only Positive) di Kampung Blekok')
plt.tight_layout()
plt.savefig('top25_aspek_positive_umbul_ponggok-after.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### WordCloud Opini Positif

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# 1. Ambil semua opini positif dan gabungkan jadi satu string
pos_list = df_flat[df_flat['Sentiment_ID'] == 'Positif']['Opinion'].dropna().tolist()
text = ' '.join(pos_list)

# Tambahkan kata penguat ke stopwords
custom_stopwords = STOPWORDS.union({'sangat', 'banget', 'sekali', 'lebih', 'juga', 'yang', 'untuk', 'dan', 
                                    'cukup', 'hanya', 'di', 'jadi', 'hanya'})

# 2. Generate wordcloud
wc = WordCloud(
    stopwords=custom_stopwords,
    width=800,
    height=400,
    background_color='white',
    collocations=False  # hindari penggabungan kata kunci yang tidak diinginkan
).generate(text)

# 3. Tampilkan
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud Opini Positif', pad=20)
plt.savefig('wordcloud_opini_positive_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Analisis Negatif ❤️‍🩹 ─ ...

# %% [markdown]
# #### Top 25 Aspek Negatif (sudah normalisasi)

# %%
stop_aspects = ['ke', 'di', 'yang', 'untuk', 'dari'] 
df_flat = df_flat[~df_flat['Aspect'].isin(stop_aspects)]

# %%
import matplotlib.pyplot as pl

# Filter hanya untuk polarity “Positive”
df_neg = df_flat[df_flat['Polarity'] == 'Negative']

# Hitung frekuensi aspek dan ambil top 25
aspect_counts = df_neg['Aspect'].value_counts().head(25)

# Urutkan ascending supaya bar terbesar di atas
aspect_counts = aspect_counts.sort_values()

# Plot
plt.figure(figsize=(8, 10))
bars = plt.barh(
    aspect_counts.index,
    aspect_counts.values,
    color='#DF362D',
    edgecolor='white',
    height=0.8
)

# Annotasi angka di ujung batang
for bar in bars:
    w = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        w + max(aspect_counts.values) * 0.01,  # sedikit ke kanan
        y,
        str(int(w)),
        va='center',
        fontsize=10
    )

plt.xlabel('Frekuensi')
plt.xlim(0, aspect_counts.values.max() * 1.15)
plt.ylabel('Aspek')
# plt.title('Top 25 Aspek Terpopuler (Only Neg) di Kampung Blekok')
plt.tight_layout()
plt.savefig('top25_aspek_negative_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Wordcloud Opini Negatif

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# 1. Ambil semua opini netral dan gabungkan jadi satu string
neg_list = df_flat[df_flat['Polarity'] == 'Negative']['Opinion'].dropna().tolist()
text = ' '.join(neg_list)

# Tambahkan kata penguat ke stopwords
custom_stopwords = STOPWORDS.union({'sangat', 'banget', 'sekali', 'lebih', 'juga', 'yang', 'untuk', 'dan', 
                                    'cukup', 'hanya', 'di', 'jadi', 'hanya'})

# 2. Generate wordcloud
wc = WordCloud(
    stopwords=custom_stopwords,
    width=800,
    height=400,
    background_color='white',
    collocations=False  # hindari penggabungan kata kunci yang tidak diinginkan
).generate(text)

# 3. Tampilkan
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud Opini Negatif', pad=20)
plt.savefig('wordcloud_opini_negative_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Analisis Netral 🐰ྀི

# %% [markdown]
# #### Top 25 Aspek Netral (sudah normalisasi)

# %%
stop_aspects = ['ke', 'di', 'yang', 'untuk', 'dari'] 
df_flat = df_flat[~df_flat['Aspect'].isin(stop_aspects)]

# %%
import matplotlib.pyplot as pl

# Filter hanya untuk polarity “Positive”
df_neu = df_flat[df_flat['Polarity'] == 'Neutral']

# Hitung frekuensi aspek dan ambil top 25
aspect_counts = df_neu['Aspect'].value_counts().head(25)

# Urutkan ascending supaya bar terbesar di atas
aspect_counts = aspect_counts.sort_values()

# Plot
plt.figure(figsize=(8, 10))
bars = plt.barh(
    aspect_counts.index,
    aspect_counts.values,
    color='#CDCDCD',
    edgecolor='white',
    height=0.8
)

# Annotasi angka di ujung batang
for bar in bars:
    w = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        w + max(aspect_counts.values) * 0.01,  # sedikit ke kanan
        y,
        str(int(w)),
        va='center',
        fontsize=10
    )

plt.xlabel('Frekuensi')
plt.xlim(0, aspect_counts.values.max() * 1.15)
plt.ylabel('Aspek')
# plt.title('Top 25 Aspek Terpopuler (Only Neu) di Kampung Blekok')
plt.tight_layout()
plt.savefig('top25_aspek_neutral_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Wordcloud Opini Netral

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# 1. Ambil semua opini netral dan gabungkan jadi satu string
neu_list = df_flat[df_flat['Polarity'] == 'Neutral']['Opinion'].dropna().tolist()
text = ' '.join(neu_list)

# Tambahkan kata penguat ke stopwords
custom_stopwords = STOPWORDS.union({'sangat', 'banget', 'sekali', 'lebih', 'juga', 'yang', 'untuk', 'dan', 
                                    'cukup', 'hanya', 'di', 'jadi', 'hanya'})

# 2. Generate wordcloud
wc = WordCloud(
    stopwords=custom_stopwords,
    width=800,
    height=400,
    background_color='white',
    collocations=False  # hindari penggabungan kata kunci yang tidak diinginkan
).generate(text)

# 3. Tampilkan
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud Opini Netral', pad=20)
plt.savefig('wordcloud_opini_neutral_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ⭐️ Top Pasangan Aspek-Opini-Sentimen

# %%
# Lakukan replace hanya pada kata utuh “seger”
df_flat['Opinion'] = df_flat['Opinion'].str.replace(
    r'\bseger\b',
    'segar',
    regex=True,
    # na_rep=None  # atau biarkan default untuk menjaga NaN tetap NaN
)

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt

# 1. Ambil seluruh data
all_df = df_flat.copy()

# 2. Hitung frekuensi pasangan Aspect–Opinion–Polarity
pair_counts = (
    all_df
    .groupby(['Aspect', 'Opinion', 'Sentiment_ID'])
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
    .head(10)
)

# 3. Plot horizontal bar chart (semua warna biru)
plt.figure(figsize=(10, 6))

# Label sekarang mencakup sentimen juga
labels = pair_counts.apply(
    lambda r: f"{r['Aspect']} – {r['Opinion']} – {r['Sentiment_ID']}", axis=1
)[::-1]
counts = pair_counts['count'][::-1]

bars = plt.barh(labels, counts, color='#9ECCFA', edgecolor='white')

# 4. Tambahkan label angka
for bar in bars:
    w = bar.get_width()
    plt.text(w + counts.max()*0.01, bar.get_y() + bar.get_height()/2,
             str(int(w)), va='center', fontsize=10)

plt.xlabel('Frekuensi')
plt.ylabel('Kombinasi Aspek Opini Sentimen')
# plt.title('Top 10 Pasangan Aspect–Opinion–Sentimen')
plt.tight_layout()
plt.savefig('top10_aos_all_sentiment_umbul_ponggok_absa.png', dpi=300, bbox_inches='tight')
plt.show()
