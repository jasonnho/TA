# %%
import torch
import transformers
import pandas as pd
import numpy as np
from transformers import BertTokenizer, BertModel
import seqeval

print(f"Torh Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
print(f"Transformers Version: {transformers.__version__}")
print("Setup Aman! Siap Gas!")
# Out:
# Torh Version: 2.5.1+cu121
# CUDA Available: True
# GPU Name: NVIDIA GeForce RTX 4060 Laptop GPU
# Transformers Version: 5.1.0
# Setup Aman! Siap Gas!

# %%
# %pip install wordcloud
# Out:
# Collecting wordcloudNote: you may need to restart the kernel to use updated packages.
#
#   Downloading wordcloud-1.9.6-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in d:\miniconda3\envs\ta_nlp\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in d:\miniconda3\envs\ta_nlp\lib\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp310-cp310-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6

# %%
# %pip install pytorch-crf seqeval
# Out:
# Collecting pytorch-crf
#   Downloading pytorch_crf-0.7.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: seqeval in d:\miniconda3\envs\ta_nlp\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from seqeval) (2.2.6)
# Requirement already satisfied: scikit-learn>=0.21.3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from seqeval) (1.7.2)
# Requirement already satisfied: scipy>=1.8.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Downloading pytorch_crf-0.7.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyabsa
# Out:
# Collecting pyabsa
#   Downloading pyabsa-2.4.3-py3-none-any.whl.metadata (14 kB)
# Collecting findfile>=2.0.0 (from pyabsa)
#   Using cached findfile-2.1.2-py3-none-any.whl.metadata (601 bytes)
# Collecting autocuda>=0.16 (from pyabsa)
#   Using cached autocuda-0.16-py3-none-any.whl.metadata (326 bytes)
# Collecting metric-visualizer>=0.9.6 (from pyabsa)
#   Using cached metric_visualizer-0.9.17-py3-none-any.whl.metadata (14 kB)
# Collecting boostaug>=2.3.5 (from pyabsa)
#   Using cached boostaug-2.3.5-py3-none-any.whl.metadata (377 bytes)
# Collecting spacy (from pyabsa)
#   Downloading spacy-3.8.14-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: networkx in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pyabsa) (3.4.2)
# Requirement already satisfied: seqeval in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pyabsa) (1.2.2)
# Collecting update-checker (from pyabsa)
#   Using cached update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing_extensions in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pyabsa) (4.15.0)
# Requirement already satisfied: tqdm in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pyabsa) (4.67.3)
# Collecting pytorch_warmup (from pyabsa)
#   Using cached pytorch_warmup-0.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting termcolor (from pyabsa)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting gitpython (from pyabsa)
#   Using cached gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<4.30.0 (from pyabsa)
#   Downloading transformers-4.29.2-py3-none-any.whl.metadata (112 kB)
# Requirement already satisfied: torch>=1.0.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pyabsa) (2.5.1+cu121)
# Requirement already satisfied: pandas in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pyabsa) (2.3.3)
# Collecting sentencepiece (from pyabsa)
#   Using cached sentencepiece-0.2.1-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in d:\miniconda3\envs\ta_nlp\lib\site-packages (from transformers<4.30.0->pyabsa) (3.20.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers<4.30.0->pyabsa)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from transformers<4.30.0->pyabsa) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from transformers<4.30.0->pyabsa) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from transformers<4.30.0->pyabsa) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from transformers<4.30.0->pyabsa) (2026.1.15)
# Requirement already satisfied: requests in d:\miniconda3\envs\ta_nlp\lib\site-packages (from transformers<4.30.0->pyabsa) (2.32.5)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<4.30.0->pyabsa)
#   Downloading tokenizers-0.13.3-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers<4.30.0->pyabsa) (2025.10.0)
# Requirement already satisfied: matplotlib>=3.6.3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from metric-visualizer>=0.9.6->pyabsa) (3.10.8)
# Collecting tikzplotlib (from metric-visualizer>=0.9.6->pyabsa)
#   Using cached tikzplotlib-0.10.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: scipy in d:\miniconda3\envs\ta_nlp\lib\site-packages (from metric-visualizer>=0.9.6->pyabsa) (1.15.3)
# Collecting tabulate (from metric-visualizer>=0.9.6->pyabsa)
#   Using cached tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Collecting natsort (from metric-visualizer>=0.9.6->pyabsa)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: click in d:\miniconda3\envs\ta_nlp\lib\site-packages (from metric-visualizer>=0.9.6->pyabsa) (8.3.1)
# Collecting openpyxl (from metric-visualizer>=0.9.6->pyabsa)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xlsxwriter (from metric-visualizer>=0.9.6->pyabsa)
#   Using cached xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: scikit-learn in d:\miniconda3\envs\ta_nlp\lib\site-packages (from metric-visualizer>=0.9.6->pyabsa) (1.7.2)
# Requirement already satisfied: colorama in d:\miniconda3\envs\ta_nlp\lib\site-packages (from metric-visualizer>=0.9.6->pyabsa) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (1.4.9)
# Requirement already satisfied: pillow>=8 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (1.17.0)
# Requirement already satisfied: jinja2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from torch>=1.0.0->pyabsa) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from torch>=1.0.0->pyabsa) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from sympy==1.13.1->torch>=1.0.0->pyabsa) (1.3.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython->pyabsa)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->pyabsa)
#   Using cached smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from jinja2->torch>=1.0.0->pyabsa) (2.1.5)
# Collecting et-xmlfile (from openpyxl->metric-visualizer>=0.9.6->pyabsa)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pytz>=2020.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pandas->pyabsa) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from pandas->pyabsa) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->transformers<4.30.0->pyabsa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->transformers<4.30.0->pyabsa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->transformers<4.30.0->pyabsa) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->transformers<4.30.0->pyabsa) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from scikit-learn->metric-visualizer>=0.9.6->pyabsa) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from scikit-learn->metric-visualizer>=0.9.6->pyabsa) (3.6.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy->pyabsa)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy->pyabsa)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy->pyabsa)
#   Using cached murmurhash-1.0.15-cp310-cp310-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy->pyabsa)
#   Using cached cymem-2.0.13-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy->pyabsa)
#   Downloading preshed-3.0.13-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy->pyabsa)
#   Downloading thinc-8.3.13-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy->pyabsa)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy->pyabsa)
#   Downloading srsly-2.5.3-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy->pyabsa)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy->pyabsa)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy->pyabsa)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy->pyabsa)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting pydantic<3.0.0,>=2.0.0 (from spacy->pyabsa)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: setuptools in d:\miniconda3\envs\ta_nlp\lib\site-packages (from spacy->pyabsa) (80.10.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->spacy->pyabsa)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.0.0->spacy->pyabsa)
#   Using cached pydantic_core-2.41.5-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.0.0->spacy->pyabsa)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy->pyabsa)
#   Using cached blis-1.3.3-cp310-cp310-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: shellingham>=1.3.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy->pyabsa) (1.5.4)
# Collecting rich>=12.3.0 (from typer<1.0.0,>=0.3.0->spacy->pyabsa)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy->pyabsa)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy->pyabsa)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy->pyabsa)
#   Using cached smart_open-7.5.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: httpx>=0.24.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy->pyabsa) (0.28.1)
# Requirement already satisfied: anyio in d:\miniconda3\envs\ta_nlp\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->pyabsa) (4.12.1)
# Requirement already satisfied: httpcore==1.* in d:\miniconda3\envs\ta_nlp\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->pyabsa) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->pyabsa) (0.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy->pyabsa)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy->pyabsa) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy->pyabsa)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting wrapt (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy->pyabsa)
#   Using cached wrapt-2.1.2-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->pyabsa) (1.3.1)
# Requirement already satisfied: webcolors in d:\miniconda3\envs\ta_nlp\lib\site-packages (from tikzplotlib->metric-visualizer>=0.9.6->pyabsa) (25.10.0)
# Downloading pyabsa-2.4.3-py3-none-any.whl (583 kB)
#    ---------------------------------------- 0.0/583.7 kB ? eta -:--:--
#    ---------------------------------------- 583.7/583.7 kB 10.0 MB/s  0:00:00
# Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.1 MB 10.7 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.1 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 11.2 MB/s  0:00:00
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Downloading tokenizers-0.13.3-cp310-cp310-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------------------------- ------------ 2.4/3.5 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 10.2 MB/s  0:00:00
# Using cached autocuda-0.16-py3-none-any.whl (5.1 kB)
# Using cached boostaug-2.3.5-py3-none-any.whl (16 kB)
# Using cached findfile-2.1.2-py3-none-any.whl (8.7 kB)
# Using cached metric_visualizer-0.9.17-py3-none-any.whl (25 kB)
# Using cached gitpython-3.1.46-py3-none-any.whl (208 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.3-py3-none-any.whl (24 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached pytorch_warmup-0.2.0-py3-none-any.whl (11 kB)
# Using cached sentencepiece-0.2.1-cp310-cp310-win_amd64.whl (1.1 MB)
# Downloading spacy-3.8.14-cp310-cp310-win_amd64.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ------ --------------------------------- 2.4/15.4 MB 12.2 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/15.4 MB 11.6 MB/s eta 0:00:01
#    ------------------- -------------------- 7.6/15.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.4 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.3/15.4 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.4 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 11.5 MB/s  0:00:01
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Using cached cymem-2.0.13-cp310-cp310-win_amd64.whl (40 kB)
# Using cached murmurhash-1.0.15-cp310-cp310-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp310-cp310-win_amd64.whl (121 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp310-cp310-win_amd64.whl (651 kB)
#    ---------------------------------------- 0.0/651.7 kB ? eta -:--:--
#    ---------------------------------------- 651.7/651.7 kB 12.6 MB/s  0:00:00
# Downloading thinc-8.3.13-cp310-cp310-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 10.9 MB/s  0:00:00
# Using cached blis-1.3.3-cp310-cp310-win_amd64.whl (6.2 MB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached smart_open-7.5.1-py3-none-any.whl (64 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached tabulate-0.10.0-py3-none-any.whl (39 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Using cached tikzplotlib-0.10.1-py3-none-any.whl (54 kB)
# Using cached update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Using cached wrapt-2.1.2-cp310-cp310-win_amd64.whl (60 kB)
# Using cached xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Installing collected packages: tokenizers, xlsxwriter, wrapt, wasabi, typing-inspection, termcolor, tabulate, spacy-loggers, spacy-legacy, smmap, sentencepiece, pydantic-core, natsort, murmurhash, mdurl, et-xmlfile, cymem, confection, cloudpathlib, catalogue, blis, autocuda, annotated-types, annotated-doc, update-checker, srsly, smart-open, pydantic, preshed, openpyxl, markdown-it-py, huggingface-hub, gitdb, findfile, transformers, tikzplotlib, thinc, rich, pytorch_warmup, gitpython, typer, metric-visualizer, weasel, spacy, boostaug, pyabsa
#
#   Attempting uninstall: tokenizers
#
#     Found existing installation: tokenizers 0.22.2
#
#     Uninstalling tokenizers-0.22.2:
#
#       Successfully uninstalled tokenizers-0.22.2
#
#    ----------------------------------------  0/46 [tokenizers]
#     ---------------------------------------  1/46 [xlsxwriter]
#     ---------------------------------------  1/46 [xlsxwriter]
#     ---------------------------------------  1/46 [xlsxwriter]
#     ---------------------------------------  1/46 [xlsxwriter]
#     ---------------------------------------  1/46 [xlsxwriter]
#     ---------------------------------------  1/46 [xlsxwriter]
#    - --------------------------------------  2/46 [wrapt]
#    -- -------------------------------------  3/46 [wasabi]
#    -- -------------------------------------  3/46 [wasabi]
#    --- ------------------------------------  4/46 [typing-inspection]
#    ----- ----------------------------------  6/46 [tabulate]
#    ------ ---------------------------------  7/46 [spacy-loggers]
#    ------ ---------------------------------  7/46 [spacy-loggers]
#    ------ ---------------------------------  8/46 [spacy-legacy]
#    ------ ---------------------------------  8/46 [spacy-legacy]
#    ------- --------------------------------  9/46 [smmap]
#    -------- ------------------------------- 10/46 [sentencepiece]
#    ---------- ----------------------------- 12/46 [natsort]
#    ---------- ----------------------------- 12/46 [natsort]
#    ----------- ---------------------------- 13/46 [murmurhash]
#    ------------ --------------------------- 14/46 [mdurl]
#    ------------- -------------------------- 16/46 [cymem]
#    -------------- ------------------------- 17/46 [confection]
#    --------------- ------------------------ 18/46 [cloudpathlib]
#    --------------- ------------------------ 18/46 [cloudpathlib]
#    --------------- ------------------------ 18/46 [cloudpathlib]
#    --------------- ------------------------ 18/46 [cloudpathlib]
#    ---------------- ----------------------- 19/46 [catalogue]
#    ----------------- ---------------------- 20/46 [blis]
#    ------------------- -------------------- 22/46 [annotated-types]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    --------------------- ------------------ 25/46 [srsly]
#    ---------------------- ----------------- 26/46 [smart-open]
#    ---------------------- ----------------- 26/46 [smart-open]
#    ---------------------- ----------------- 26/46 [smart-open]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ----------------------- ---------------- 27/46 [pydantic]
#    ------------------------ --------------- 28/46 [preshed]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    ------------------------- -------------- 29/46 [openpyxl]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 30/46 [markdown-it-py]
#   Attempting uninstall: huggingface-hub
#    -------------------------- ------------- 30/46 [markdown-it-py]
#     Found existing installation: huggingface_hub 1.4.1
#    -------------------------- ------------- 30/46 [markdown-it-py]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#     Uninstalling huggingface_hub-1.4.1:
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#       Successfully uninstalled huggingface_hub-1.4.1
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    -------------------------- ------------- 31/46 [huggingface-hub]
#    --------------------------- ------------ 32/46 [gitdb]
#    --------------------------- ------------ 32/46 [gitdb]
#    --------------------------- ------------ 32/46 [gitdb]
#    ---------------------------- ----------- 33/46 [findfile]
#   Attempting uninstall: transformers
#    ---------------------------- ----------- 33/46 [findfile]
#     Found existing installation: transformers 5.1.0
#    ---------------------------- ----------- 33/46 [findfile]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#     Uninstalling transformers-5.1.0:
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#       Successfully uninstalled transformers-5.1.0
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ----------------------------- ---------- 34/46 [transformers]
#    ------------------------------ --------- 35/46 [tikzplotlib]
#    ------------------------------ --------- 35/46 [tikzplotlib]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    ------------------------------- -------- 36/46 [thinc]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    -------------------------------- ------- 37/46 [rich]
#    --------------------------------- ------ 38/46 [pytorch_warmup]
#    --------------------------------- ------ 39/46 [gitpython]
#    --------------------------------- ------ 39/46 [gitpython]
#    --------------------------------- ------ 39/46 [gitpython]
#    --------------------------------- ------ 39/46 [gitpython]
#    --------------------------------- ------ 39/46 [gitpython]
#    ---------------------------------- ----- 40/46 [typer]
#    ---------------------------------- ----- 40/46 [typer]
#    ---------------------------------- ----- 40/46 [typer]
#    ----------------------------------- ---- 41/46 [metric-visualizer]
#    ----------------------------------- ---- 41/46 [metric-visualizer]
#    ------------------------------------ --- 42/46 [weasel]
#    ------------------------------------ --- 42/46 [weasel]
#    ------------------------------------ --- 42/46 [weasel]
#    ------------------------------------ --- 42/46 [weasel]
#    ------------------------------------ --- 42/46 [weasel]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    ------------------------------------- -- 43/46 [spacy]
#    -------------------------------------- - 44/46 [boostaug]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------  45/46 [pyabsa]
#    ---------------------------------------- 46/46 [pyabsa]
#
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 autocuda-0.16 blis-1.3.3 boostaug-2.3.5 catalogue-2.0.10 cloudpathlib-0.23.0 confection-1.3.3 cymem-2.0.13 et-xmlfile-2.0.0 findfile-2.1.2 gitdb-4.0.12 gitpython-3.1.46 huggingface-hub-0.36.2 markdown-it-py-4.0.0 mdurl-0.1.2 metric-visualizer-0.9.17 murmurhash-1.0.15 natsort-8.4.0 openpyxl-3.1.5 preshed-3.0.13 pyabsa-2.4.3 pydantic-2.12.5 pydantic-core-2.41.5 pytorch_warmup-0.2.0 rich-14.3.3 sentencepiece-0.2.1 smart-open-7.5.1 smmap-5.0.3 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 tabulate-0.10.0 termcolor-3.3.0 thinc-8.3.13 tikzplotlib-0.10.1 tokenizers-0.13.3 transformers-4.29.2 typer-0.24.1 typing-inspection-0.4.2 update-checker-0.18.0 wasabi-1.1.3 weasel-1.0.0 wrapt-2.1.2 xlsxwriter-3.2.9
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install dash
# Out:
# Collecting dash
#   Downloading dash-4.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting Flask<3.2,>=1.0.4 (from dash)
#   Downloading flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.2 (from dash)
#   Downloading werkzeug-3.1.7-py3-none-any.whl.metadata (4.0 kB)
# Collecting plotly>=5.0.0 (from dash)
#   Downloading plotly-6.6.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting importlib-metadata (from dash)
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in d:\miniconda3\envs\ta_nlp\lib\site-packages (from dash) (2.32.5)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in d:\miniconda3\envs\ta_nlp\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in d:\miniconda3\envs\ta_nlp\lib\site-packages (from dash) (80.10.2)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: click>=8.1.3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.3.1)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.1.5)
# Requirement already satisfied: colorama in d:\miniconda3\envs\ta_nlp\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Collecting narwhals>=1.15.1 (from plotly>=5.0.0->dash)
#   Downloading narwhals-2.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in d:\miniconda3\envs\ta_nlp\lib\site-packages (from plotly>=5.0.0->dash) (25.0)
# Collecting zipp>=3.20 (from importlib-metadata->dash)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->dash) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->dash) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->dash) (2026.1.4)
# Downloading dash-4.1.0-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.2 MB 11.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 11.2 MB/s  0:00:00
# Downloading flask-3.1.3-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.7-py3-none-any.whl (226 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading plotly-6.6.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.9 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 11.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 11.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.8 MB/s  0:00:00
# Downloading narwhals-2.18.1-py3-none-any.whl (444 kB)
# Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, Werkzeug, retrying, narwhals, itsdangerous, blinker, plotly, importlib-metadata, Flask, dash
#
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    ---- -----------------------------------  1/10 [Werkzeug]
#    -------- -------------------------------  2/10 [retrying]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ------------ ---------------------------  3/10 [narwhals]
#    ---------------- -----------------------  4/10 [itsdangerous]
#    -------------------- -------------------  5/10 [blinker]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ------------------------ ---------------  6/10 [plotly]
#    ---------------------------- -----------  7/10 [importlib-metadata]
#    -------------------------------- -------  8/10 [Flask]
#    -------------------------------- -------  8/10 [Flask]
#    -------------------------------- -------  8/10 [Flask]
#    -------------------------------- -------  8/10 [Flask]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ------------------------------------ ---  9/10 [dash]
#    ---------------------------------------- 10/10 [dash]
#
# Successfully installed Flask-3.1.3 Werkzeug-3.1.7 blinker-1.9.0 dash-4.1.0 importlib-metadata-9.0.0 itsdangerous-2.2.0 narwhals-2.18.1 plotly-6.6.0 retrying-1.4.2 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install PySastrawi
# Out:
# Requirement already satisfied: PySastrawi in d:\miniconda3\envs\ta_nlp\lib\site-packages (1.2.0)Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall Sastrawi PySastrawi -y
# Out:
# Found existing installation: Sastrawi 1.0.1
# Uninstalling Sastrawi-1.0.1:
#   Successfully uninstalled Sastrawi-1.0.1
# Found existing installation: PySastrawi 1.2.0
# Uninstalling PySastrawi-1.2.0:
#   Successfully uninstalled PySastrawi-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install PySastrawi
# Out:
# Collecting PySastrawi
#   Using cached PySastrawi-1.2.0-py2.py3-none-any.whl.metadata (892 bytes)
# Using cached PySastrawi-1.2.0-py2.py3-none-any.whl (210 kB)
# Installing collected packages: PySastrawi
# Successfully installed PySastrawi-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show PySastrawi
# Out:
# Name: PySastrawi
# Version: 1.2.0
# Summary: Library for stemming Indonesian (Bahasa) text
# Home-page: https://github.com/har07/PySastrawi
# Author: Hanif Amal Robbani
# Author-email: dev.har07@gmail.com
# License: MIT
# Location: d:\miniconda3\envs\ta_nlp\lib\site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
print(dir(factory))
# Out:
# ['APC_KEY', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'create_stemmer', 'get_words', 'get_words_from_file']

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: pyyaml in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface_hub>=0.21.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in d:\miniconda3\envs\ta_nlp\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: requests in d:\miniconda3\envs\ta_nlp\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: networkx in d:\miniconda3\envs\ta_nlp\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in d:\miniconda3\envs\ta_nlp\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\miniconda3\envs\ta_nlp\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.13.0
